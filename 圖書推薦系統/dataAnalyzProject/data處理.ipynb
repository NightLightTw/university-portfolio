# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("data/1文學小說.csv",encoding='utf-8')
data2=pd.read_csv("data/2商業理財.csv",encoding='utf-8')
data3=pd.read_csv("data/3藝術設計.csv",encoding='utf-8')
data4=pd.read_csv("data/4人文社科.csv",encoding='utf-8')
data5=pd.read_csv("data/6自然科普.csv",encoding='utf-8')
data6=pd.read_csv("data/7心理勵志.csv",encoding='utf-8')
data7=pd.read_csv("data/8醫療保健.csv",encoding='utf-8')
data8=pd.read_csv("data/9飲食.csv",encoding='utf-8')
data9=pd.read_csv("data/10生活風格.csv",encoding='utf-8')
data10=pd.read_csv("data/11旅遊.csv",encoding='utf-8')
data11=pd.read_csv("data/12宗教命理.csv",encoding='utf-8')
data12=pd.read_csv("data/13親子教養.csv",encoding='utf-8')
data13=pd.read_csv("data/14童書_青少年文學.csv",encoding='utf-8')
data14=pd.read_csv("data/15輕小說.csv",encoding='utf-8')
data15=pd.read_csv("data/16漫畫_圖文書.csv",encoding='utf-8')
data16=pd.read_csv("data/17語言學習.csv",encoding='utf-8')
data17=pd.read_csv("data/18考試用書.csv",encoding='utf-8')
data18=pd.read_csv("data/19電腦資訊.csv",encoding='utf-8')
data19=pd.read_csv("data/20專業_教科書_政府出版品.csv",encoding='utf-8')
data20=pd.read_csv("data/22影視偶像.csv",encoding='utf-8')
data21=pd.read_csv("data/24國中小參考書.csv",encoding='utf-8')

# %%
data1=data1.drop(columns=['圖片網址','內容','商品連結'])
data2=data2.drop(columns=['圖片網址','內容','商品連結'])
data3=data3.drop(columns=['圖片網址','內容','商品連結'])
data4=data4.drop(columns=['圖片網址','內容','商品連結'])
data5=data5.drop(columns=['圖片網址','內容','商品連結'])
data6=data6.drop(columns=['圖片網址','內容','商品連結'])
data7=data7.drop(columns=['圖片網址','內容','商品連結'])
data8=data8.drop(columns=['圖片網址','內容','商品連結'])
data9=data9.drop(columns=['圖片網址','內容','商品連結'])
data10=data10.drop(columns=['圖片網址','內容','商品連結'])
data11=data11.drop(columns=['圖片網址','內容','商品連結'])
data12=data12.drop(columns=['圖片網址','內容','商品連結'])
data13=data13.drop(columns=['圖片網址','內容','商品連結'])
data14=data14.drop(columns=['圖片網址','內容','商品連結'])
data15=data15.drop(columns=['圖片網址','內容','商品連結'])
data16=data16.drop(columns=['圖片網址','內容','商品連結'])
data17=data17.drop(columns=['圖片網址','內容','商品連結'])
data18=data18.drop(columns=['圖片網址','內容','商品連結'])
data19=data19.drop(columns=['圖片網址','內容','商品連結'])
data20=data20.drop(columns=['圖片網址','內容','商品連結'])
data21=data21.drop(columns=['圖片網址','內容','商品連結'])

# %%
frames=[data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13,data14,data15,data16,data17,data18,data19,data20,data21]
df = pd.concat(frames,ignore_index=True)
df
# Out:
#           分類                                書名       作者   出版社        出版日期  \
# 0       文學小說                       村上T 我愛的那些T恤     村上春樹  時報出版  2022/05/31
# 1       文學小說  六個說謊的大學生【博客來獨家書衣版】（2022年本屋大賞第5名）     淺倉秋成  采實文化  2022/05/05
# 2       文學小說           百鬼夜行卷8：狼人（月夜狼嚎PVC夜光書衣版）       笭菁  奇幻基地  2022/06/02
# 3       文學小說      在說出再見之前【百萬暢銷小說《在咖啡冷掉之前》迸淚續作】     川口俊和  悅知文化  2022/04/27
# 4       文學小說       綾羅歌．卷一～卷二．獨家限量作者親簽精緻燙金典藏書盒版       鄭丰  奇幻基地  2022/06/02
# ...      ...                               ...      ...   ...         ...
# 3867  國中小參考書                   彩圖‧新版天天閱讀（中年級2）      賴慶雄   螢火蟲  2022/06/06
# 3868  國中小參考書                    活力成語100分 一年級新綱      黃美麗    世一  2022/05/13
# 3869  國中小參考書                           這篇童話有意思  世一文化編輯群    世一  2022/06/13
# 3870  國中小參考書                           這些對話有意思  世一文化編輯群    世一  2022/06/13
# 3871  國中小參考書                            這個人有意思  世一文化編輯群    世一  2022/06/13
#
#                優惠價                                                也買了
# ...

# %%
df.to_csv('data/all.csv')

# %%
data1
# Out:
#        分類                                書名  \
# 0    文學小說                       村上T 我愛的那些T恤
# 1    文學小說  六個說謊的大學生【博客來獨家書衣版】（2022年本屋大賞第5名）
# 2    文學小說           百鬼夜行卷8：狼人（月夜狼嚎PVC夜光書衣版）
# 3    文學小說      在說出再見之前【百萬暢銷小說《在咖啡冷掉之前》迸淚續作】
# 4    文學小說       綾羅歌．卷一～卷二．獨家限量作者親簽精緻燙金典藏書盒版
# ..    ...                               ...
# 598  文學小說                           黃金召喚師39
# 599  文學小說                          拔劍就是真理18
# 600  文學小說                             牧龍師56
# 601  文學小說                        投靠親戚進高門 卷二
# 602  文學小說                        投靠親戚進高門 卷三
#
#                                                   圖片網址    作者   出版社  \
# 0    https://www.books.com.tw/img/001/092/46/001092...  村上春樹  時報出版
# 1    https://www.books.com.tw/img/001/092/26/001092...  淺倉秋成  采實文化
# 2    https://www.books.com.tw/img/001/092/46/001092...    笭菁  奇幻基地
# 3    https://www.books.com.tw/img/001/092/22/001092...  川口俊和  悅知文化
# 4    https://www.books.com.tw/img/001/092/47/001092...    鄭丰  奇幻基地
# ...
